# %% [markdown]
# ## Evaluation Project - 5
#
# ### Census Income Project
#
# #### Problem Statement:
#
#
#         This data was extracted from the 1994 Census bureau database by Ronny Kohavi and Barry Becker (Data Mining and Visualization, Silicon Graphics). A set of reasonably clean records was extracted using the following conditions:
#             ((AAGE>16) && (AGI>100) && (AFNLWGT>1) && (HRSWK>0)). The prediction task is to determine whether a person makes over$50K a year.

# %% [markdown]
# #### Description of fnlwgt (final weight)
#
#     The weights on the Current Population Survey (CPS) files are controlled to independent estimates of the civilian non-institutional population of the US. These are prepared monthly for us by Population Division here at the Census Bureau. We use 3 sets of controls. These are:
#
#     A single cell estimate of the population 16+ for each state.
#
#     Controls for Hispanic Origin by age and sex.
#
#     Controls by Race, age and sex.
#
#     We use all three sets of controls in our weighting program and "rake" through them 6 times so that by the end we come back to all the controls we used. The term estimate refers to population totals derived from CPS by creating "weighted tallies" of any specified socio-economic characteristics of the population. People with similar demographic characteristics should have similar weights. There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.
#
#
#
#     To download the dataset, use the link given below.

# %% [markdown]
# ### STEP 1 : DATA PREPARATION
#     - Loading imports
#     - loading Dataset
#     - Checking dtypes of Data
#     - Checking information about data, STD , duplicate data , null/ missing values.

# %%
#IMPORTING IMPORTS

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score,RandomizedSearchCV

# %%
train = pd.read_csv('census.csv')

# %%
train
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
train.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# #### OBSERVATIONS:
#     - Captital Gain / loss have 75% quantile value (75% of Data is 0)around 0 , and only few vlaues are high, makes it unrelaisitic effection our model.
#     - WE will visualize more in later step to decide how to treat these features.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# CHECKING FOR MISSING VLAUES

# %%
(train.isnull()).sum(axis=0)
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
for i in train.columns:
    print(train[i].value_counts())
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: Age, Length: 73, dtype: int64
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# 123011    13
# 203488    13
# 164190    13
# 121124    12
# 148995    12
#           ..
# 68318      1
# 284211     1
# 312881     1
# 177711     1
# 229376     1
# Name: Fnlwgt, Length: 21647, dtype: int64
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64
# 9     10501
# 10     7291
# 13     5354
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: Education_num, dtype: int64
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 4931         1
# 1455         1
# 6097         1
# 22040        1
# 1111         1
# Name: Capital_gain, Length: 119, dtype: int64
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 1411        1
# 1539        1
# 2472        1
# 1944        1
# 2201        1
# Name: Capital_loss, Length: 92, dtype: int64
# 40    15216
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 92        1
# 94        1
# 87        1
# 74        1
# 82        1
# Name: Hours_per_week, Length: 94, dtype: int64
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %% [markdown]
# #### OBSERVATIONS:
#     - 9 Categorical Features.
#     - 5 Numerical Features.
#     - Income is Target Variable (CAtegorical)
#
#
#     - Work Class has missing Values with '?'
#     -  Occupation has missing Values with '?'
#     -  Native_country has missing Values with '?'

# %%
train['Workclass'] = train['Workclass'].apply(lambda x : np.NaN if (x.find('?')>0) else x)
train['Occupation'] = train['Occupation'].apply(lambda x : np.NaN if (x.find('?')>0) else x)
train['Native_country'] = train['Native_country'].apply(lambda x : np.NaN if (x.find('?')>0) else x)

# %%
(train.isnull()).sum(axis=0)
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     583
# Income               0
# dtype: int64

# %%
sb.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### AS ALL THE MISSING VALUES ARE Categorical Values, we Use MODE TO FILL THE MISSING VALUES.

# %%
train['Workclass'] = train['Workclass'].fillna(train['Workclass'].mode()[0])
train['Occupation'] = train['Occupation'].fillna(train['Occupation'].mode()[0])  
train['Native_country'] = train['Native_country'].fillna(train['Native_country'].mode()[0])

# %% [markdown]
# # EDA:
#     - Understanding Relationships between variables.
#     - Univariante, Bivariante, Multivariante Analysis.

# %% [markdown]
# ### CHECKNIG THE TARGET CLASS COUNTPLOT

# %%
from plotnine import *

# %%
plt.figure(figsize=(8,6))
sb.countplot(train['Income'],palette='PuRd')
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# #### OBSERVATION: TARGET CLASS IMBALANCED
#         --->  Applying Undersampling for EDA PUrposes,
#         ---> OverSampling/Undersampling for Modelling.

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
y = train['Income']
x = train.drop('Income',axis=1)
rus = RandomUnderSampler(random_state=0)
rus.fit(x,y)
# Out:
# RandomUnderSampler(random_state=0)

# %%
x_resampled, y_resampled = rus.fit_resample(x,y)

# %%
sb.countplot(y_resampled)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# #### NOTE:
#     WE USE BALANCED CLASSES FOR VISUALIZATION TO GET MORE INFORMATION ON MINORITY CLASS, as it difficult to get information when the classes are imblanced

# %%
x_resampled['Income'] = y_resampled

# %%
x_resampled['Income'].value_counts()
# Out:
#  >50K     7841
#  <=50K    7841
# Name: Income, dtype: int64

# %% [markdown]
# ### VIZUALIZING BOTH WITH IMBALANCED / bALANCED CLASS FOR BETTER INFORMATION

# %%
ggplot(x_resampled, aes(x='Income', fill = 'Workclass')) + \
    geom_bar(stat = 'count')
# Out:
# <ggplot: (168736202897)>

# %% [markdown]
# ####  observations:
#     - IT SEEMS >50K has higher count of Self-emp-not-inc, self-imploy-inc, local-gov, Federal-gov than <=50K
#     - Private has greter count for <=50K
#
#     - As with-out pay, Never=worked is hard to visualize, we get the data and visualize

# %%
train[(train['Workclass']==' Without-pay' )|(train['Workclass']==' Never-worked' ) ]
# Out:
#        Age      Workclass  Fnlwgt      Education  Education_num  \
# 1900    65    Without-pay   27012        7th-8th              4
# 5360    18   Never-worked  206359           10th              6
# 9256    19    Without-pay  344858        HS-grad              9
# 10844   23   Never-worked  188535        7th-8th              4
# 14771   17   Never-worked  237272           10th              6
# 15532   21    Without-pay  232719        HS-grad              9
# 15694   22    Without-pay  302347        HS-grad              9
# 16811   46    Without-pay  142210        HS-grad              9
# 20072   65    Without-pay  172949        HS-grad              9
# 20336   18   Never-worked  157131           11th              7
# 21943   52    Without-pay  198262        HS-grad              9
# 22214   19    Without-pay   43887        HS-grad              9
# 23231   20   Never-worked  462294   Some-college             10
# 24595   62    Without-pay  170114     Assoc-acdm             12
# 25499   29    Without-pay  212588   Some-college             10
# 27746   72    Without-pay  121004        HS-grad              9
# 28828   68    Without-pay  174695   Some-college             10
# 29157   67    Without-pay  137192        HS-grad              9
# 32261   62    Without-pay  159908   Some-college             10
# 32303   30   Never-worked  176673        HS-grad              9
# 32313   18   Never-worked  153663   Some-college             10
#
#                Marital_status          Occupation    Relationship  \
# 1900                  Widowed     Farming-fishing       Unmarried
# 5360            Never-married      Prof-specialty       Own-child
# 9256            Never-married     Farming-fishing       Own-child
# 10844                Divorced      Prof-specialty   Not-in-family
# 14771           Never-married      Prof-specialty       Own-child
# 15532           Never-married        Craft-repair       Own-child
# 15694           Never-married   Handlers-cleaners       Own-child
# 16811      Married-civ-spouse   Machine-op-inspct            Wife
# 20072      Married-civ-spouse    Transport-moving         Husband
# 20336           Never-married      Prof-specialty       Own-child
# 21943      Married-civ-spouse        Adm-clerical            Wife
# 22214           Never-married     Farming-fishing       Own-child
# 23231           Never-married      Prof-specialty       Own-child
# 24595      Married-civ-spouse     Farming-fishing         Husband
# 25499      Married-civ-spouse     Farming-fishing       Own-child
# 27746      Married-civ-spouse       Other-service         Husband
# 28828   Married-spouse-absent     Farming-fishing       Unmarried
# 29157      Married-civ-spouse        Adm-clerical         Husband
# 32261      Married-civ-spouse        Adm-clerical            Wife
# 32303      Married-civ-spouse      Prof-specialty            Wife
# 32313           Never-married      Prof-specialty       Own-child
#
#                       Race      Sex  Capital_gain  Capital_loss  \
# 1900                 White   Female             0             0
# 5360                 White     Male             0             0
# 9256                 White     Male             0             0
# 10844                White     Male             0             0
# 14771                White     Male             0             0
# 15532                Black     Male             0             0
# 15694                White     Male          4416             0
# 16811                White   Female             0             0
# 20072                White     Male          2414             0
# 20336                White   Female             0             0
# 21943                White   Female             0             0
# 22214                White     Male             0             0
# 23231                Black     Male             0             0
# 24595                White     Male             0             0
# 25499                White     Male             0             0
# 27746                White     Male             0             0
# 28828                White   Female             0             0
# 29157   Asian-Pac-Islander     Male             0             0
# 32261                White   Female             0             0
# 32303                Black   Female             0             0
# 32313                White     Male             0             0
#
#        Hours_per_week  Native_country  Income
# 1900               50   United-States   <=50K
# 5360               40   United-States   <=50K
# 9256               20   United-States   <=50K
# 10844              35   United-States   <=50K
# 14771              30   United-States   <=50K
# 15532              40   United-States   <=50K
# 15694              40   United-States   <=50K
# 16811              25   United-States   <=50K
# 20072              20   United-States   <=50K
# 20336              10   United-States   <=50K
# 21943              30   United-States   <=50K
# 22214              10   United-States   <=50K
# 23231              40   United-States   <=50K
# 24595              50   United-States   <=50K
# 25499              65   United-States   <=50K
# 27746              55   United-States   <=50K
# 28828              25   United-States   <=50K
# 29157              12     Philippines   <=50K
# 32261              16   United-States   <=50K
# 32303              40   United-States   <=50K
# 32313               4   United-States   <=50K

# %% [markdown]
# ### AS you can see Never-worked, without pay always has <=50K, we can assume this category has high probabiltiy to belong to <=50K , WE can merge this categories together.

# %%
train['Workclass'] = train['Workclass'].apply(lambda x:'NotWorked/WithoutPay' if((x==' Never-worked') |(x==' Without-pay' ))
                                                 else x
                                             )

# %% [markdown]
# #### COUNTPLOT OF EDUCATION WRT to INCOME

# %%
ggplot(x_resampled, aes(x='Income', fill = 'Education')) + \
    geom_bar(stat = 'count')
# Out:
# <ggplot: (168736196928)>

# %% [markdown]
# #### OBSERVATIONS:
#     - income with >50K has Greater count of Bachlors/ doctorate, Being a Bachelors probability to belong is >50K is higher.
#     - For HS-Grad, probabability to belong in <=50K is higher.
#
#     - As kids in scholl are definately more probability to belong in <=50K , we can group it and reduced the no of categories.

# %%
ggplot(x_resampled, aes(x='Income', fill = 'Marital_status')) + \
    geom_bar(stat = 'count')
# Out:
# <ggplot: (168743032908)>

# %% [markdown]
# ##### OBSERVATIONS:
#     -Higher probability of Married-civ-spouse to belong to >50K.
#     - Higher probability of Never-Married/Divorced/Widowed to belong to <=50K.
#
#        - AS Married AF Spouse/ Married -spous- Absent has a very low count , we can merge it with some category.WE can create a group for

# %%
ggplot(x_resampled, aes(x='Income', fill = 'Occupation')) + \
    geom_bar(stat = 'count')
# Out:
# <ggplot: (168745410717)>

# %% [markdown]
# #### OBSERVATIONS:
#     - HIgh probability for occupations Prof-Speicality, Sales, Exec-Manegerial to belong to >50K.
#     - High Probability for Occupations other-services,,handles-cleaner,Adm-clerical to belong in <=50K

# %%
ggplot(x_resampled, aes(x='Income', fill = 'Relationship')) + \
    geom_bar(stat = 'count')
# Out:
# <ggplot: (168748946225)>

# %% [markdown]
# #### OBSERVATIONS:
#     - Husbands/ Wife have higher probability to belong in >50K.
#     - Own-Child,Unmarried,other relative. has Higher probability to belnog to <=50K.

# %%
ggplot(x_resampled, aes(x='Income', fill = 'Race')) + \
    geom_bar(stat = 'count')
# Out:
# <ggplot: (168750169293)>

# %% [markdown]
# #### OBSERVATIONS:
#     - Black RAce have high probability to belong in <=50K.

# %%
ggplot(x_resampled, aes(x='Income', fill = 'Sex')) + \
    geom_bar(stat = 'count')
# Out:
# <ggplot: (168750484194)>

# %% [markdown]
# #### OBSERVATIONS:
#     - MAles have higher probability to belong in >50K. And Females have High count in <=50K

# %%
ggplot(x_resampled, aes(x='Income', fill = 'Native_country')) + \
    geom_bar(stat = 'count')
# Out:
# <ggplot: (168750130167)>

# %% [markdown]
# #### OBSERVATIONS:
#     - more than 90% count belongs to USA, and other 10% to different countries, making it less of information and more noise.
#     - AS USA in influencing more and other countries are influencing less to the target variable , we can group all other countries to a Seperate categroy as Others, and USA.

# %%
sb.countplot(x_resampled['Education_num'],hue=x_resampled['Income'])
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='count'>

# %% [markdown]
# #### OBSERVATIONS:
#     - <=50K has higher probability of lower values of Education nums.
#     - >50K has higher probability for number of Education nums.

# %%
sb.violinplot(x_resampled['Income'],x_resampled['Education_num'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Education_num'>

# %% [markdown]
# #### VIsualizing continous Variable with Income

# %%
sb.kdeplot(x_resampled['Age'],hue=x_resampled['Income'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sb.barplot(x_resampled['Income'],x_resampled['Age'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Age'>

# %% [markdown]
# #### OBSERVATIONS:
#     - MEan AGe of >50K is higher than  <=50K

# %%
train.groupby(by='Income').mean()
# Out:
#               Age         Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Income
#  <=50K  36.783648  190345.429467       9.594927    148.670537     53.145071
#  >50K   44.249841  188005.000000      11.611657   4006.142456    195.001530
#
#         Hours_per_week
# Income
#  <=50K       38.840163
#  >50K        45.473026

# %%
sb.barplot(x_resampled['Income'],x_resampled['Fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Fnlwgt'>

# %%
sb.barplot(train['Income'],train['Fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Fnlwgt'>

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
sb.barplot(x_resampled['Income'],x_resampled['Capital_gain'])


plt.figure(figsize=(10,7))
plt.subplot(2,2,2)
sb.barplot(x_resampled['Income'],x_resampled['Capital_loss'])
plt.show()

# %% [markdown]
# #### Average Capital Loss/Gain less for <=50K

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
sb.scatterplot(x_resampled['Income'],x_resampled['Capital_gain'])


plt.figure(figsize=(10,7))
plt.subplot(2,2,2)
sb.scatterplot(x_resampled['Income'],x_resampled['Capital_loss'])
plt.show()

# %% [markdown]
# #### OBSERVATIONS:
#     -- IN Captital Loss, >50K has concentrated between 1500-3500.
#     -- high Captital gain has high probability to belong to >50K

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
sb.scatterplot(train['Income'],train['Capital_gain'])


plt.figure(figsize=(10,7))
plt.subplot(2,2,2)
sb.scatterplot(train['Income'],train['Capital_loss'])
plt.show()

# %% [markdown]
# #### CAPITAL LOSS HAS MORE INFLUENCE ON INCOME AS IT HAS MORE DIFINED BOUNDARIES THAN CAPITAL GAIN

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
sb.boxenplot(train['Income'],train['Capital_gain'])


plt.figure(figsize=(10,7))
plt.subplot(2,2,2)
sb.boxenplot(train['Income'],train['Capital_loss'])
plt.show()

# %% [markdown]
# #### OBSERVATIONS:
#     -  Capital gain has high boundary, where as captital gain for <=50K is very low.
#     - Captital Loss  has more defined boundary to compare between >50K and <-50K

# %%
sb.scatterplot(x_resampled['Hours_per_week'],x_resampled['Income'])
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='Income'>

# %%
sb.barplot(x_resampled['Hours_per_week'],x_resampled['Income'])
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='Income'>

# %% [markdown]
# ##### Hours per week are higher for >50K
# ### LABEL ENCODING with LABELEncoder : categorical Variables

# %%
from sklearn.preprocessing import LabelEncoder

# %%
train
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
### CHANGING NATIVE COUNNTRY OTHER THAN USA TO OTHERS

# %%
train['Native_country'] = train['Native_country'].apply(lambda x :'USA' if(x ==' United-States') else 'Others')

# %%
train.Native_country.value_counts()
# Out:
# USA       29752
# Others     2808
# Name: Native_country, dtype: int64

# %%
train
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week Native_country  \
# 0         Male             0             0              13            USA
# 1         Male             0             0              40            USA
# 2         Male             0             0              40            USA
# 3       Female             0             0              40         Others
# 4       Female             0             0              40            USA
# ...        ...           ...           ...             ...            ...
# 32555   Female             0             0              38            USA
# 32556     Male             0             0              40            USA
# 32557   Female             0             0              40            USA
# 32558     Male             0             0              20            USA
# 32559   Female         15024             0              40            USA
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
cat_col =['Workclass','Education','Marital_status','Occupation','Relationship','Race','Sex','Native_country','Income']

# %%
for i in cat_col:
    train[i] = LabelEncoder().fit_transform(train[i] )

# %%
train
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          4   83311          9             13               2
# 1       38          2  215646         11              9               0
# 2       53          2  234721          1              7               2
# 3       28          2  338409          9             13               2
# 4       37          2  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          2  257302          7             12               2
# 32556   40          2  154374         11              9               2
# 32557   58          2  151910         11              9               6
# 32558   22          2  201490         11              9               4
# 32559   52          3  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0               3             0     4    1             0             0
# 1               5             1     4    1             0             0
# 2               5             0     2    1             0             0
# 3               9             5     2    0             0             0
# 4               3             5     4    0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32555          12             5     4    0             0             0
# 32556           6             0     4    1             0             0
# 32557           0             4     4    0             0             0
# 32558           0             3     4    1             0             0
# 32559           3             5     4    0         15024             0
#
#        Hours_per_week  Native_country  Income
# 0                  13               1       0
# 1                  40               1       0
# 2                  40               1       0
# 3                  40               0       0
# 4                  40               1       0
# ...               ...             ...     ...
# 32555              38               1       0
# 32556              40               1       1
# 32557              40               1       0
# 32558              20               1       0
# 32559              40               1       1
#
# [32560 rows x 15 columns]

# %%
train.Income.value_counts()
# 0 ==> <=50K
# 1 ==> >50K
# Out:
# 0    24719
# 1     7841
# Name: Income, dtype: int64

# %%
plt.figure(figsize=(14,12))
sb.heatmap(train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
train.Native_country.value_counts()
# Out:
# 1    29752
# 0     2808
# Name: Native_country, dtype: int64

# %% [markdown]
# #### CHECKNIG DISTRIBUTION OF CONTINOUS VARIABLES

# %%
cont = ['Fnlwgt','Capital_gain','Capital_loss','Age','Hours_per_week']

# %% [markdown]
# ### AS VALUES OF CAPTITAL GAIN AND LOSS ARE CONSIDERABLY HIGH, and outlier mgiht remove inportant information

# %%
for i in cont:
    plt.figure()
    sb.kdeplot(train[i])
    plt.legend(['Skewness: '+str(train[i].skew())])

# %% [markdown]
# ### CHECKNIG FOR OUTLIERS

# %%
train.iloc[:,0:7].boxplot(figsize=[20,10])
plt.subplots_adjust(bottom=.25)
plt.show()

# %%
train.iloc[:,7:].boxplot(figsize=[20,10])
plt.subplots_adjust(bottom=.25)
plt.show()

# %% [markdown]
# #### Captial gain/loss/ fnlwgt / hours _per _Week has outliers

# %%
from scipy.stats import zscore

# %%
train[cont].skew()
# Out:
# Fnlwgt             1.446972
# Capital_gain      11.953690
# Capital_loss       4.594549
# Age                0.558738
# Hours_per_week     0.227636
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer

# %%
train[cont] = PowerTransformer().fit_transform(train[cont])

# %%
train[cont].skew()
# Out:
# Fnlwgt            0.016914
# Capital_gain      3.016951
# Capital_loss      4.299511
# Age              -0.013897
# Hours_per_week    0.229556
# dtype: float64

# %%
scores = np.abs(zscore(train))

# %%
len(np.where(scores>3)[0])
# Out:
# 10471

# %%
train
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.891947          4 -1.089889          9             13
# 1      0.102717          2  0.398743         11              9
# 2      1.064381          2  0.562540          1              7
# 3     -0.731663          2  1.340398          9             13
# 4      0.028023          2  0.957182         12             14
# ...         ...        ...       ...        ...            ...
# 32555 -0.827983          2  0.746749          7             12
# 32556  0.247374          2 -0.193298         11              9
# 32557  1.334556          2 -0.219755         11              9
# 32558 -1.358341          2  0.271668         11              9
# 32559  1.007823          3  0.982165         11              9
#
#        Marital_status  Occupation  Relationship  Race  Sex  Capital_gain  \
# 0                   2           3             0     4    1     -0.301370
# 1                   0           5             1     4    1     -0.301370
# 2                   2           5             0     2    1     -0.301370
# 3                   2           9             5     2    0     -0.301370
# 4                   2           3             5     4    0     -0.301370
# ...               ...         ...           ...   ...  ...           ...
# 32555               2          12             5     4    0     -0.301370
# 32556               2           6             0     4    1     -0.301370
# 32557               6           0             4     4    0     -0.301370
# 32558               4           0             3     4    1     -0.301370
# 32559               2           3             5     4    0      3.318234
#
#        Capital_loss  Hours_per_week  Native_country  Income
# 0         -0.221213       -2.221515               1       0
# 1         -0.221213       -0.035570               1       0
# 2         -0.221213       -0.035570               1       0
# 3         -0.221213       -0.035570               0       0
# 4         -0.221213       -0.035570               1       0
# ...             ...             ...             ...     ...
# 32555     -0.221213       -0.197550               1       0
# 32556     -0.221213       -0.035570               1       1
# 32557     -0.221213       -0.035570               1       0
# 32558     -0.221213       -1.654992               1       0
# 32559     -0.221213       -0.035570               1       1
#
# [32560 rows x 15 columns]

# %% [markdown]
# #### DATA MODELLING

# %%
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

import scikitplot as skplt
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import roc_auc_score,roc_curve,f1_score,recall_score,precision_score

# %%
x = train.drop('Income',axis=1)
y = train['Income']

# %% [markdown]
# ### SMOTE FOR OVERSAMPLER

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# %%
x_over,y_over = SMOTE().fit_resample(x,y)
x_under,y_under = RandomUnderSampler().fit_resample(x,y)

# %%
    randomstate = 0
    max_score = 0
    lr = LogisticRegression()
    for i in range(1,50):
        x_train,x_test,y_train,y_test = train_test_split(x_over,y_over,test_size=.30,random_state=i)
        lr.fit(x_train,y_train)
        pred = lr.predict(x_test)
        score = f1_score(y_test,pred)    
        if(score>max_score):
            max_score = score
            randomstate  = i
    print( 'Random State=',randomstate,' and R2 Score of LR MODEL : ',max_score)
# Out:
# Random State= 37  and R2 Score of LR MODEL :  0.7811626978847944

# %%
    randomstate = 0
    max_score = 0
    lr = LogisticRegression()
    for i in range(1,50):
        x_train,x_test,y_train,y_test = train_test_split(x_under,y_under ,test_size=.30,random_state=i)
        lr.fit(x_train,y_train)
        pred = lr.predict(x_test)
        score = f1_score(y_test,pred)    
        if(score>max_score):
            max_score = score
            randomstate  = i
    print( 'Random State=',randomstate,' and R2 Score of LR MODEL : ',max_score)
# Out:
# Random State= 40  and R2 Score of LR MODEL :  0.7815038533638826

# %% [markdown]
# #### AS UNDERSAMPLING/ OVer Sampling gives Same Results, we go with OverSampling , to not lose DAta.

# %% [markdown]
# ### MODELING THE DATA :
#     - WE choose metrics for the model as f-1 score, and roc_auc score, recall ,precision as imbalanced classes , we need to check if the model is not biased towards the majority class.

# %%
    model = LGBMClassifier()
    randomstate = 0
    max_score = 0
    
    for i in range(1,200):
        x_train,x_test,y_train,y_test = train_test_split(x_over,y_over ,test_size=.30,random_state=i)
        model.fit(x_train,y_train)
        pred = model.predict(x_test)
        score = f1_score(y_test,pred)    
        if(score>max_score):
            max_score = score
            randomstate  = i
    print('BEST Random State: ',randomstate,' With F1- Score : ',max_score)
# Out:
# BEST Random State:  132  With F1- Score :  0.9052815952573431

# %%
x_train,x_test,y_train,y_test = train_test_split(x_over,y_over ,test_size=.27,random_state=132)

# %%
cv_scores = []
auc_roc_scores = []
acc_scores = []
f1_scores = []

# %%
def model_predict(model):
    model.fit(x_train,y_train)
    predictions = model.predict(x_test)
    pred_proba = model.predict_proba(x_test)[:,1]
    fpr,tpr,threshold = roc_curve(y_test,pred_proba)
     
    print('------------',model,'--------------')
    print(' Accuracy Score         : ', accuracy_score(y_test,predictions))
    print('ROC AUC Score           : ', roc_auc_score(y_test,pred_proba))
    print('F1 Score                :',f1_score(y_test,predictions))
    print('Cross Validation Score  : ',np.mean(cross_val_score(model,x_over,y_over,cv=5,scoring='f1')))
    
    
    print(classification_report(y_test,predictions))
    acc_scores.append(accuracy_score(y_test,predictions))
    cv_scores.append(np.mean(cross_val_score(model,x_over,y_over,cv=5,scoring='f1')))
    auc_roc_scores.append(roc_auc_score(y_test,pred_proba))
    f1_scores.append(f1_score(y_test,predictions))
    
    plt.figure(figsize=(8,5))
    plt.plot(fpr,tpr)
    plt.ylabel('Sensitivity')
    plt.xlabel('1 - Specificity')
    leg = 'ROC CURVE SCORE:'+ str(roc_auc_score(y_test,pred_proba))
    plt.legend( [leg],loc= 10)
    
    
    plt.figure()
    skplt.metrics.plot_confusion_matrix(y_test,predictions)

# %% [markdown]
# ### LOGISTIC REGRESSION

# %%
model_predict(LogisticRegression())
# Out:
# ------------ LogisticRegression() --------------
#  Accuracy Score         :  0.7735410892201663
# ROC AUC Score           :  0.8518585686216806
# F1 Score                : 0.7778349378996103
# Cross Validation Score  :  0.7736875683564917
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77      6654
#            1       0.77      0.79      0.78      6695
#
#     accuracy                           0.77     13349
#    macro avg       0.77      0.77      0.77     13349
# weighted avg       0.77      0.77      0.77     13349

# %% [markdown]
# ### KNN

# %%
acc = []
for i in range(1,20):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(x_train,y_train)
    predictions = model.predict(x_test)
    pred_prob = model.predict_proba(x_test)[:,1]
    acc.append(roc_auc_score(y_test,pred_prob))

# %%
plt.figure(figsize=(10,7))
plt.plot(range(1,20),acc)
plt.xlabel('K values')
plt.ylabel('auc roc score')
plt.xlim(1,20,)
# Out:
# (1.0, 20.0)

# %%
model_predict(KNeighborsClassifier(n_neighbors=9))
# Out:
# ------------ KNeighborsClassifier(n_neighbors=9) --------------
#  Accuracy Score         :  0.8429095812420406
# ROC AUC Score           :  0.9160800816547706
# F1 Score                : 0.8543446551364867
# Cross Validation Score  :  0.8542237412637252
#               precision    recall  f1-score   support
#
#            0       0.90      0.77      0.83      6654
#            1       0.80      0.92      0.85      6695
#
#     accuracy                           0.84     13349
#    macro avg       0.85      0.84      0.84     13349
# weighted avg       0.85      0.84      0.84     13349

# %% [markdown]
# #### DECISION TREE:

# %%
model_predict(DecisionTreeClassifier())
# Out:
# ------------ DecisionTreeClassifier() --------------
#  Accuracy Score         :  0.8414113416735336
# ROC AUC Score           :  0.8413852264036547
# F1 Score                : 0.8431503297028969
# Cross Validation Score  :  0.8364659502412082
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      6654
#            1       0.84      0.85      0.84      6695
#
#     accuracy                           0.84     13349
#    macro avg       0.84      0.84      0.84     13349
# weighted avg       0.84      0.84      0.84     13349

# %%
model_predict(RandomForestClassifier())
# Out:
# ------------ RandomForestClassifier() --------------
#  Accuracy Score         :  0.8915274552400929
# ROC AUC Score           :  0.9590369873035092
# F1 Score                : 0.894059116183787
# Cross Validation Score  :  0.8914226337425666
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      6654
#            1       0.88      0.91      0.89      6695
#
#     accuracy                           0.89     13349
#    macro avg       0.89      0.89      0.89     13349
# weighted avg       0.89      0.89      0.89     13349

# %%
model_predict(XGBClassifier())
# Out:
# [18:15:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ------------ XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None) --------------
#  Accuracy Score         :  0.9071091467525657
# ROC AUC Score           :  0.9725670184852341
# F1 Score                : 0.9073105097921963
# [18:15:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:15:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:15:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:15:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:15:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Cross Validation Score  :  0.8761035438525875
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      6654
#            1       0.91      0.91      0.91      6695
#
#     accuracy                           0.91     13349
#    macro avg       0.91      0.91      0.91     13349
# weighted avg       0.91      0.91      0.91     13349
#
# [18:20:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:20:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:20:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:20:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:20:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
model_predict(LGBMClassifier())
# Out:
# ------------ LGBMClassifier() --------------
#  Accuracy Score         :  0.9047868754213799
# ROC AUC Score           :  0.9711701710471703
# F1 Score                : 0.9055369751021924
# Cross Validation Score  :  0.8785639341297665
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90      6654
#            1       0.90      0.91      0.91      6695
#
#     accuracy                           0.90     13349
#    macro avg       0.90      0.90      0.90     13349
# weighted avg       0.90      0.90      0.90     13349

# %%
model_predict(AdaBoostClassifier())
# Out:
# ------------ AdaBoostClassifier() --------------
#  Accuracy Score         :  0.844707468724249
# ROC AUC Score           :  0.9307719132370923
# F1 Score                : 0.8481652384091408
# Cross Validation Score  :  0.8447366056352175
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84      6654
#            1       0.83      0.86      0.85      6695
#
#     accuracy                           0.84     13349
#    macro avg       0.85      0.84      0.84     13349
# weighted avg       0.85      0.84      0.84     13349

# %%
error = []
for i in range(0,7):
    error.append(np.abs(f1_scores[i] - cv_scores[i]))

# %%
table_dict = {
    'ROC AUC SCORE: ':auc_roc_scores,
    'ACCURACY SCORE': acc_scores,
    'CV SCORE': cv_scores,
    'F1 SCORE': f1_scores,
    'Bias/ Error': error
}

# %%
table_model = pd.DataFrame(table_dict,index=['LReg','KNN','DTC','RF','XGBC','LightGBMC','ADABoost'])

# %%
table_model
# Out:
#            ROC AUC SCORE:   ACCURACY SCORE  CV SCORE  F1 SCORE  Bias/ Error
# LReg              0.851859        0.773541  0.773688  0.777835     0.004147
# KNN               0.916080        0.842910  0.854224  0.854345     0.000121
# DTC               0.841385        0.841411  0.837277  0.843150     0.005873
# RF                0.959037        0.891527  0.892186  0.894059     0.001873
# XGBC              0.972567        0.907109  0.876104  0.907311     0.031207
# LightGBMC         0.971170        0.904787  0.878564  0.905537     0.026973
# ADABoost          0.930772        0.844707  0.844737  0.848165     0.003429

# %% [markdown]
# #### OBSERVATION:
#     - Evaluation MEtrics choosen is F1 SCORE as it it checks recall score and Precision score for both the classes. as other evaluatioin metrics might  give biases score for majority class.
#
#     - HIghest F1 Score/ ROC AUC is for XGBC and LightGB.
#
#     - Error/ Bias term is least for KNN. But AS Error terms for ther models are not that huge, are are considerablely close to each other, we can use the model highest f1 score to hyper TUNE.
#
#     - MODEL CHOOSEN: XGBC

# %% [markdown]
# ### HYPER PARAMETER TUNING

# %%
params = {
    'n_estimators': [50,100,200],
    'max_depth': [5,10,15,7],
    'learning_rate': [0.1,.5,.2,0.01],
    'gamma': [.1,.5,1,2],
    'subsample': [1,.8,.75,.6],
    'min_child_weight': [1,3,5,2]
    
    
}

# %%
boost = XGBClassifier()
grid = RandomizedSearchCV(boost,params,cv=5,n_iter=50,scoring='f1',verbose=2)

# %%
grid.fit(x_over,y_over)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [18:52:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=15, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   2.4s
# [18:52:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=15, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   2.3s
# [18:52:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=15, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   2.4s
# [18:52:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=15, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   2.3s
# [18:52:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=15, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   2.6s
# [18:52:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=15, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   8.6s
# [18:53:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=15, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   8.4s
# [18:53:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=15, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   8.5s
# [18:53:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=15, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   8.2s
# [18:53:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=15, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   8.2s
# [18:53:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=200, subsample=1; total time=   4.8s
# [18:53:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=200, subsample=1; total time=   4.8s
# [18:53:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=200, subsample=1; total time=   4.7s
# [18:53:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=200, subsample=1; total time=   4.8s
# [18:54:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=200, subsample=1; total time=   4.7s
# [18:54:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=15, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   2.2s
# [18:54:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=15, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   2.3s
# [18:54:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=15, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   2.8s
# [18:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=15, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   2.3s
# [18:54:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=15, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   2.3s
# [18:54:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   4.9s
# [18:54:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   4.9s
# [18:54:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   4.9s
# [18:54:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   4.9s
# [18:54:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   4.9s
# [18:54:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=50, subsample=0.8; total time=   1.3s
# [18:54:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=50, subsample=0.8; total time=   1.3s
# [18:54:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=50, subsample=0.8; total time=   1.3s
# [18:54:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=50, subsample=0.8; total time=   1.3s
# [18:54:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=50, subsample=0.8; total time=   1.2s
# [18:54:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   4.2s
# [18:54:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   4.3s
# [18:54:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   4.3s
# [18:55:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   4.3s
# [18:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   4.3s
# [18:55:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=50, subsample=0.6; total time=   1.6s
# [18:55:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=50, subsample=0.6; total time=   1.6s
# [18:55:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=50, subsample=0.6; total time=   1.6s
# [18:55:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=50, subsample=0.6; total time=   1.6s
# [18:55:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=50, subsample=0.6; total time=   1.7s
# [18:55:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.75; total time=   2.7s
# [18:55:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.75; total time=   2.7s
# [18:55:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.75; total time=   2.7s
# [18:55:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.75; total time=   2.7s
# [18:55:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.75; total time=   2.7s
# [18:55:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   1.2s
# [18:55:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   1.2s
# [18:55:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   1.1s
# [18:55:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   1.2s
# [18:55:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   1.2s
# [18:55:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, subsample=0.8; total time=   3.8s
# [18:55:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, subsample=0.8; total time=   3.8s
# [18:55:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, subsample=0.8; total time=   3.8s
# [18:55:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, subsample=0.8; total time=   3.8s
# [18:55:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, subsample=0.8; total time=   3.8s
# [18:55:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=50, subsample=0.75; total time=   0.9s
# [18:56:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=50, subsample=0.75; total time=   0.9s
# [18:56:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=50, subsample=0.75; total time=   0.9s
# [18:56:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=50, subsample=0.75; total time=   0.9s
# [18:56:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=50, subsample=0.75; total time=   0.9s
# [18:56:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=1; total time=   5.5s
# [18:56:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=1; total time=   5.5s
# [18:56:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=1; total time=   5.4s
# [18:56:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=1; total time=   5.7s
# [18:56:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=1; total time=   5.5s
# [18:56:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.5, max_depth=15, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   4.7s
# [18:56:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.5, max_depth=15, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   4.8s
# [18:56:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.5, max_depth=15, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   4.9s
# [18:56:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.5, max_depth=15, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.0s
# [18:56:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.5, max_depth=15, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   4.8s
# [18:56:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   8.9s
# [18:57:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   8.9s
# [18:57:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   9.1s
# [18:57:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   8.9s
# [18:57:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=200, subsample=0.6; total time=   8.9s
# [18:57:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   0.8s
# [18:57:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   0.8s
# [18:57:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   0.8s
# [18:57:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   0.8s
# [18:57:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   0.8s
# [18:57:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.7s
# [18:57:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.7s
# [18:57:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.7s
# [18:58:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.7s
# [18:58:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.1, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   4.7s
# [18:58:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   3.4s
# [18:58:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   3.4s
# [18:58:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   3.4s
# [18:58:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   3.4s
# [18:58:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   3.4s
# [18:58:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=50, subsample=0.6; total time=   1.1s
# [18:58:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=50, subsample=0.6; total time=   1.2s
# [18:58:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=50, subsample=0.6; total time=   1.1s
# [18:58:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=50, subsample=0.6; total time=   1.1s
# [18:58:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=50, subsample=0.6; total time=   1.1s
# [18:58:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=100, subsample=1; total time=   3.6s
# [18:58:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=100, subsample=1; total time=   3.6s
# [18:58:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=100, subsample=1; total time=   3.6s
# [18:58:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=100, subsample=1; total time=   3.5s
# [18:58:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=100, subsample=1; total time=   3.6s
# [18:58:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   4.1s
# [18:58:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   4.3s
# [18:59:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   4.3s
# [18:59:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   4.3s
# [18:59:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=15, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   4.3s
# [18:59:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.75; total time=   7.2s
# [18:59:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.75; total time=   7.0s
# [18:59:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.75; total time=   7.0s
# [18:59:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.75; total time=   7.0s
# [18:59:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.75; total time=   7.1s
# ...
# [19:07:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   1.7s
# [19:07:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=0.5, learning_rate=0.5, max_depth=10, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   1.7s
# [19:07:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=2, n_estimators=200, subsample=0.75; total time=   3.7s
# [19:07:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=2, n_estimators=200, subsample=0.75; total time=   3.7s
# [19:07:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=2, n_estimators=200, subsample=0.75; total time=   3.6s
# [19:07:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=2, n_estimators=200, subsample=0.75; total time=   3.7s
# [19:07:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=2, n_estimators=200, subsample=0.75; total time=   3.7s
# [19:07:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=100, subsample=1; total time=   5.5s
# [19:07:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=100, subsample=1; total time=   5.5s
# [19:07:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=100, subsample=1; total time=   5.5s
# [19:08:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=100, subsample=1; total time=   5.5s
# [19:08:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=100, subsample=1; total time=   5.5s
# [19:08:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   1.3s
# [19:08:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   1.2s
# [19:08:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   1.2s
# [19:08:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   1.3s
# [19:08:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=50, subsample=0.75; total time=   1.2s
# [19:08:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   3.5s
# [19:08:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   3.5s
# [19:08:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   3.5s
# [19:08:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   3.5s
# [19:08:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   3.5s
# [19:08:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.1s
# [19:08:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.3s
# [19:08:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.2s
# [19:08:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.1s
# [19:08:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=1, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   5.0s
# [19:09:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   3.7s
# [19:09:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   4.0s
# [19:09:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   3.7s
# [19:09:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   3.7s
# [19:09:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV] END gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8; total time=   4.0s
# [19:09:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, gamma=None,
#                                            gpu_id=None, importance_type='gain',
#                                            interaction_constraints=None,
#                                            learning_rate=None,
#                                            max_delta_step=None, max_depth=None,
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            n_estimators=100,...
#                                            random_state=None, reg_alpha=None,
#                                            reg_lambda=None,
#                                            scale_pos_weight=None,
#                                            subsample=None, tree_method=None,
#                                            validate_parameters=None,
#                                            verbosity=None),
#                    n_iter=50,
#                    param_distributions={'gamma': [0.1, 0.5, 1, 2],
#                                         'learning_rate': [0.1, 0.5, 0.2, 0.01],
#                                         'max_depth': [5, 10, 15, 7],
#                                         'min_child_weight': [1, 3, 5, 2],
#                                         'n_estimators': [50, 100, 200],
#                                         'subsample': [1, 0.8, 0.75, 0.6]},
#                    scoring='f1', verbose=2)

# %%
grid.best_params_,grid.best_score_
# Out:
# ({'subsample': 1,
#   'n_estimators': 200,
#   'min_child_weight': 1,
#   'max_depth': 15,
#   'learning_rate': 0.1,
#   'gamma': 1},
#  0.879835944390635)

# %%
model_predict(XGBClassifier(subsample=1,n_estimators=200,
                            min_child_weight=1,max_depth=15,
                            learning_rate=0.1,gamma=1
                             ))
# Out:
# [19:10:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ------------ XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=1, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.1, max_delta_step=0, max_depth=15,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=200, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None) --------------
#  Accuracy Score         :  0.9060603790546108
# ROC AUC Score           :  0.9725332014322358
# F1 Score                : 0.9066269545793001
# [19:10:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:10:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:10:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:11:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:11:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Cross Validation Score  :  0.879835944390635
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      6654
#            1       0.90      0.91      0.91      6695
#
#     accuracy                           0.91     13349
#    macro avg       0.91      0.91      0.91     13349
# weighted avg       0.91      0.91      0.91     13349
#
# [19:11:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:11:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:11:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:12:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:12:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
params_lgbr = {
    'num_leaves': [70,80,50,40,20],
    'max_depth': [5,7,10,12,15],
   
    'bagging_freq': [5,10,15,7,12], 
    "bagging_fraction": [0.75,.6,.5,.8,.85,.7],
    'learning_rate': [.01,.02,.1,.5]
}
LightGBR = LGBMClassifier()
grid_l= RandomizedSearchCV(LightGBR,params_lgbr,cv=5,scoring='f1',n_iter=30,verbose=2,n_jobs=5)

# %%
grid_l.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# RandomizedSearchCV(cv=5, estimator=LGBMClassifier(), n_iter=30, n_jobs=5,
#                    param_distributions={'bagging_fraction': [0.75, 0.6, 0.5,
#                                                              0.8, 0.85, 0.7],
#                                         'bagging_freq': [5, 10, 15, 7, 12],
#                                         'learning_rate': [0.01, 0.02, 0.1, 0.5],
#                                         'max_depth': [5, 7, 10, 12, 15],
#                                         'num_leaves': [70, 80, 50, 40, 20]},
#                    scoring='f1', verbose=2)

# %%
grid_l.best_score_,grid_l.best_estimator_
# Out:
# (0.894234273476626,
#  LGBMClassifier(bagging_fraction=0.75, bagging_freq=15, max_depth=12,
#                 num_leaves=70))

# %%
model_predict( LGBMClassifier(bagging_fraction=0.75, bagging_freq=15, max_depth=12,
                num_leaves=70))
# Out:
# ------------ LGBMClassifier(bagging_fraction=0.75, bagging_freq=15, max_depth=12,
#                num_leaves=70) --------------
#  Accuracy Score         :  0.9071091467525657
# ROC AUC Score           :  0.9724728178460659
# F1 Score                : 0.9076281287246722
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# Cross Validation Score  :  0.8829491775571064
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      6654
#            1       0.91      0.91      0.91      6695
#
#     accuracy                           0.91     13349
#    macro avg       0.91      0.91      0.91     13349
# weighted avg       0.91      0.91      0.91     13349
#
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15

# %% [markdown]
# #### OBSERVATION:
#     - BOTH LightGB, XGB have have same f1-scores, and other precision, precall scores.
#     - Light GB More TP,TN than XGB.
#     - FINAL MODEL : LightGB

# %% [markdown]
# ## EVALUATING LightGBClassifier

# %%
    model = LGBMClassifier(bagging_fraction=0.75, bagging_freq=15,
                           max_depth=12,num_leaves=70)
    
    model.fit(x_train,y_train)
    predictions = model.predict(x_test)
    pred_proba = model.predict_proba(x_test)[:,1]
    fpr,tpr,threshold = roc_curve(y_test,pred_proba)
     
    print('------------',model,'--------------')
    print(' Accuracy Score         : ', accuracy_score(y_test,predictions))
    print('ROC AUC Score           : ', roc_auc_score(y_test,pred_proba))
    print('F1 Score                :',f1_score(y_test,predictions))
    print('Precision Score         :',precision_score(y_test,predictions))
    print('Recall Score         :',recall_score(y_test,predictions))
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# ------------ LGBMClassifier(bagging_fraction=0.75, bagging_freq=15, max_depth=12,
#                num_leaves=70) --------------
#  Accuracy Score         :  0.9071091467525657
# ROC AUC Score           :  0.9724728178460659
# F1 Score                : 0.9076281287246722
# Precision Score         : 0.9053351166592362
# Recall Score         : 0.909932785660941

# %%
 print('Cross Validation Score  : ',np.mean(cross_val_score(model,x_over,y_over,cv=10,scoring='f1')))
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# Cross Validation Score  :  0.8912963160857844

# %%
print(confusion_matrix(y_test,predictions
                      ))
print(classification_report(y_test,predictions))
# Out:
# [[6017  637]
#  [ 603 6092]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      6654
#            1       0.91      0.91      0.91      6695
#
#     accuracy                           0.91     13349
#    macro avg       0.91      0.91      0.91     13349
# weighted avg       0.91      0.91      0.91     13349

# %%
 
    plt.figure(figsize=(8,5))
    plt.plot(fpr,tpr)
    plt.ylabel('Sensitivity')
    plt.xlabel('1 - Specificity')
    leg = 'ROC CURVE SCORE:'+ str(roc_auc_score(y_test,pred_proba))
    plt.legend( [leg],loc= 10)
    
    
    plt.figure()
    skplt.metrics.plot_confusion_matrix(y_test,predictions)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# ### SAVING THE MODEL

# %%
import joblib as jb

# %%
jb.dump(model,'census_lgbc.pk1')
# Out:
# ['census_lgbc.pk1']

# %%
jb.load('census_lgbc.pk1')
# Out:
# LGBMClassifier(bagging_fraction=0.75, bagging_freq=15, max_depth=12,
#                num_leaves=70)

# %% [markdown]
# ### CONCLUSION:
#
#          WE have build a model with LightGBM Classifer MODel with an AUC ROC ACCuracy of .972 , PRecision, Recall and F1 Score with .90 and total accuracy score of .90.
#          - WE doont have a model biased towards 1 class.
#          - WE have a model that is able to predict both the classes of target variable with same precision, recall.
